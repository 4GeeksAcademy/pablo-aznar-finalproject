# %%
import pandas as pd
from glob import glob
import os
from utils import cargar_y_unificar, limpiar_clave
import pickle

# %%
data_dir = '../data/raw/accidents_causa_vianant'
# Buscar todos los CSV de la carpeta
accident_files = sorted(glob(os.path.join(data_dir, "*.csv")))
accident_files
# Out:
# ['../data/raw/accidents_causa_vianant/2017_accidents_gu_bcn.csv',
#  '../data/raw/accidents_causa_vianant/2018_accidents_gu_bcn.csv',
#  '../data/raw/accidents_causa_vianant/2019_accidents_gu_bcn.csv',
#  '../data/raw/accidents_causa_vianant/2020_accidents_gu_bcn.csv',
#  '../data/raw/accidents_causa_vianant/2021_accidents_gu_bcn.csv',
#  '../data/raw/accidents_causa_vianant/2022_accidents_gu_bcn.csv',
#  '../data/raw/accidents_causa_vianant/2023_accidents_gu_bcn.csv',
#  '../data/raw/accidents_causa_vianant/2024_accidents_gu_bcn.csv']

# %%
# Leer y unir todos los archivos
df_accidents = pd.concat([pd.read_csv(file) for file in accident_files], ignore_index=True)
df_accidents
# Out:
#       Numero_expedient  Codi_districte   Nom_districte Codi_barri  \
# 0      2017S008429                  -1      Desconegut         -1
# 1      2017S007316                  -1      Desconegut         -1
# 2      2017S010210                  -1      Desconegut         -1
# 3      2017S006364                  -1      Desconegut         -1
# 4      2017S004615                  10      Sant Martí         64
# ...                ...             ...             ...        ...
# 67483      2024S007547               2        Eixample          7
# 67484      2024S007548               1    Ciutat Vella          4
# 67485      2024S007549               3  Sants-Montjuïc         11
# 67486      2024S007550               3  Sants-Montjuïc         11
# 67487      2024S007551               1    Ciutat Vella          1
#
#                                    Nom_barri  Codi_carrer  \
# 0                                 Desconegut           -1
# 1                                 Desconegut           -1
# 2                                 Desconegut           -1
# 3                                 Desconegut           -1
# 4                 el Camp de l'Arpa del Clot       226400
# ...                                      ...          ...
# 67483                 la Dreta de l'Eixample       169409
# 67484  Sant Pere, Santa Caterina i la Ribera       143100
# 67485                           el Poble Sec       198804
# 67486                           el Poble Sec       234001
# 67487                               el Raval       701367
#
#                                               Nom_carrer  Num_postal  \
# 0      Número 27                                     ...  Desconegut
# 1      Número 3 Zona Franca / Número 50 Zona Franca  ...  Desconegut
# 2      Litoral (Besòs)                               ...  K128
# 3      Número 3 Zona Franca                          ...  77-111
# 4      Las Navas de Tolosa                           ...   0323 0325
# ...                                                  ...         ...
# 67483                                    Corts Catalanes         NaN
# 67484                          General Álvarez de Castro         NaN
# 67485                                          Paral·lel         NaN
# 67486                                            Olímpic         NaN
# 67487                                              Raval         NaN
#
#       Descripcio_dia_setmana Dia_setmana  ... Coordenada_UTM_Y  Longitud  \
# 0                  Divendres          Dv  ...       4577079.15  2.125624
# 1                  Divendres          Dv  ...       4577014.83  2.120452
# 2                  Divendres          Dv  ...       4579358.49  2.167356
# 3                  Divendres          Dv  ...       4576816.19  2.124529
# 4                     Dijous          Dj  ...       4585503,52  2.185272
# ...                      ...         ...  ...              ...       ...
# 67483                Dimarts         NaN  ...              NaN       NaN
# 67484               Dissabte         NaN  ...              NaN       NaN
# 67485                 Dijous         NaN  ...              NaN       NaN
# 67486                Dilluns         NaN  ...              NaN       NaN
# 67487              Divendres         NaN  ...              NaN       NaN
#
#          Latitud Num_postal   Num_postal_caption  NK_Any  \
# 0      41.340045         NaN                 NaN     NaN
# 1      41.339426         NaN                 NaN     NaN
# 2      41.360886         NaN                 NaN     NaN
# 3      41.337668         NaN                 NaN     NaN
# 4      41.416365         NaN                 NaN     NaN
# ...          ...         ...                 ...     ...
# 67483        NaN         603                 NaN  2024.0
# 67484        NaN         2-4                 NaN  2024.0
# 67485        NaN         NaN                 NaN  2024.0
# 67486        NaN         1-3                 NaN  2024.0
# 67487        NaN         25X                 NaN  2024.0
#
#       Coordenada_UTM_X_ED50 Coordenada_UTM_Y_ED50  Longitud_WGS84  \
# 0                       NaN                   NaN             NaN
# 1                       NaN                   NaN             NaN
# 2                       NaN                   NaN             NaN
# 3                       NaN                   NaN             NaN
# 4                       NaN                   NaN             NaN
# ...                     ...                   ...             ...
# 67483           4582460.824            430450.705        2.167002
# 67484           4582233.737            431382.242        2.178169
# 67485            4580940.29            428989.313        2.149703
# 67486           4579426.054            429206.725        2.152479
# 67487           4581341.695            430668.432        2.169734
#
#        Latitud_WGS84
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 67483      41.388825
# 67484      41.386859
# 67485      41.375002
# 67486      41.361383
# 67487      41.378764
#
# [67488 rows x 34 columns]

# %%
df_accidents['Nom_districte'].value_counts()
# Out:
# Nom_districte
# Eixample               19131
# Sant Martí              8345
# Sants-Montjuïc          7380
# Sarrià-Sant Gervasi     7288
# Horta-Guinardó          4996
# Les Corts               4637
# Sant Andreu             4482
# Nou Barris              3836
# Ciutat Vella            3767
# Gràcia                  3367
# Desconegut               259
# Name: count, dtype: int64

# %%
df_accidents.shape
# Out:
# (67488, 34)

# %%
df_accidents.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67488 entries, 0 to 67487
# Data columns (total 34 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Numero_expedient           67488 non-null  object
#  1   Codi_districte             67488 non-null  int64
#  2   Nom_districte              67488 non-null  object
#  3   Codi_barri                 67488 non-null  object
#  4   Nom_barri                  67488 non-null  object
#  5   Codi_carrer                67488 non-null  int64
#  6   Nom_carrer                 67486 non-null  object
#  7   Num_postal                 10339 non-null  object
#  8   Descripcio_dia_setmana     67488 non-null  object
#  9   Dia_setmana                36570 non-null  object
#  10  Descripcio_tipus_dia       36570 non-null  object
#  11  Any                        20275 non-null  float64
#  12  Mes_any                    67488 non-null  int64
#  13  Nom_mes                    67488 non-null  object
#  14  Dia_mes                    67488 non-null  int64
#  15  Hora_dia                   67488 non-null  int64
#  16  Descripcio_torn            67488 non-null  object
#  17  Descripcio_causa_vianant   60423 non-null  object
#  18  Numero_morts               59963 non-null  float64
#  19  Numero_lesionats_lleus     66480 non-null  float64
#  20  Numero_lesionats_greus     60193 non-null  float64
#  21  Numero_victimes            66672 non-null  float64
#  22  Numero_vehicles_implicats  67488 non-null  int64
#  23  Coordenada_UTM_X           36570 non-null  object
#  24  Coordenada_UTM_Y           36570 non-null  object
#  25  Longitud                   44569 non-null  float64
#  26  Latitud                    44569 non-null  float64
#  27  Num_postal                 17283 non-null  object
#  28  Num_postal_caption         31953 non-null  object
#  29  NK_Any                     47213 non-null  float64
#  30  Coordenada_UTM_X_ED50      30918 non-null  object
#  31  Coordenada_UTM_Y_ED50      30918 non-null  object
#  32  Longitud_WGS84             22895 non-null  float64
#  33  Latitud_WGS84              22895 non-null  float64
# dtypes: float64(10), int64(6), object(18)
# memory usage: 17.5+ MB

# %%
df_accidents
# Out:
#       Numero_expedient  Codi_districte   Nom_districte Codi_barri  \
# 0      2017S008429                  -1      Desconegut         -1
# 1      2017S007316                  -1      Desconegut         -1
# 2      2017S010210                  -1      Desconegut         -1
# 3      2017S006364                  -1      Desconegut         -1
# 4      2017S004615                  10      Sant Martí         64
# ...                ...             ...             ...        ...
# 67483      2024S007547               2        Eixample          7
# 67484      2024S007548               1    Ciutat Vella          4
# 67485      2024S007549               3  Sants-Montjuïc         11
# 67486      2024S007550               3  Sants-Montjuïc         11
# 67487      2024S007551               1    Ciutat Vella          1
#
#                                    Nom_barri  Codi_carrer  \
# 0                                 Desconegut           -1
# 1                                 Desconegut           -1
# 2                                 Desconegut           -1
# 3                                 Desconegut           -1
# 4                 el Camp de l'Arpa del Clot       226400
# ...                                      ...          ...
# 67483                 la Dreta de l'Eixample       169409
# 67484  Sant Pere, Santa Caterina i la Ribera       143100
# 67485                           el Poble Sec       198804
# 67486                           el Poble Sec       234001
# 67487                               el Raval       701367
#
#                                               Nom_carrer  Num_postal  \
# 0      Número 27                                     ...  Desconegut
# 1      Número 3 Zona Franca / Número 50 Zona Franca  ...  Desconegut
# 2      Litoral (Besòs)                               ...  K128
# 3      Número 3 Zona Franca                          ...  77-111
# 4      Las Navas de Tolosa                           ...   0323 0325
# ...                                                  ...         ...
# 67483                                    Corts Catalanes         NaN
# 67484                          General Álvarez de Castro         NaN
# 67485                                          Paral·lel         NaN
# 67486                                            Olímpic         NaN
# 67487                                              Raval         NaN
#
#       Descripcio_dia_setmana Dia_setmana  ... Coordenada_UTM_Y  Longitud  \
# 0                  Divendres          Dv  ...       4577079.15  2.125624
# 1                  Divendres          Dv  ...       4577014.83  2.120452
# 2                  Divendres          Dv  ...       4579358.49  2.167356
# 3                  Divendres          Dv  ...       4576816.19  2.124529
# 4                     Dijous          Dj  ...       4585503,52  2.185272
# ...                      ...         ...  ...              ...       ...
# 67483                Dimarts         NaN  ...              NaN       NaN
# 67484               Dissabte         NaN  ...              NaN       NaN
# 67485                 Dijous         NaN  ...              NaN       NaN
# 67486                Dilluns         NaN  ...              NaN       NaN
# 67487              Divendres         NaN  ...              NaN       NaN
#
#          Latitud Num_postal   Num_postal_caption  NK_Any  \
# 0      41.340045         NaN                 NaN     NaN
# 1      41.339426         NaN                 NaN     NaN
# 2      41.360886         NaN                 NaN     NaN
# 3      41.337668         NaN                 NaN     NaN
# 4      41.416365         NaN                 NaN     NaN
# ...          ...         ...                 ...     ...
# 67483        NaN         603                 NaN  2024.0
# 67484        NaN         2-4                 NaN  2024.0
# 67485        NaN         NaN                 NaN  2024.0
# 67486        NaN         1-3                 NaN  2024.0
# 67487        NaN         25X                 NaN  2024.0
#
#       Coordenada_UTM_X_ED50 Coordenada_UTM_Y_ED50  Longitud_WGS84  \
# 0                       NaN                   NaN             NaN
# 1                       NaN                   NaN             NaN
# 2                       NaN                   NaN             NaN
# 3                       NaN                   NaN             NaN
# 4                       NaN                   NaN             NaN
# ...                     ...                   ...             ...
# 67483           4582460.824            430450.705        2.167002
# 67484           4582233.737            431382.242        2.178169
# 67485            4580940.29            428989.313        2.149703
# 67486           4579426.054            429206.725        2.152479
# 67487           4581341.695            430668.432        2.169734
#
#        Latitud_WGS84
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 67483      41.388825
# 67484      41.386859
# 67485      41.375002
# 67486      41.361383
# 67487      41.378764
#
# [67488 rows x 34 columns]

# %%
df_accidents.isnull().sum().sort_values(ascending=False)
# Out:
# Num_postal                   57149
# Num_postal                   50205
# Any                          47213
# Latitud_WGS84                44593
# Longitud_WGS84               44593
# Coordenada_UTM_Y_ED50        36570
# Coordenada_UTM_X_ED50        36570
# Num_postal_caption           35535
# Coordenada_UTM_X             30918
# Coordenada_UTM_Y             30918
# Descripcio_tipus_dia         30918
# Dia_setmana                  30918
# Longitud                     22919
# Latitud                      22919
# NK_Any                       20275
# Numero_morts                  7525
# Numero_lesionats_greus        7295
# Descripcio_causa_vianant      7065
# Numero_lesionats_lleus        1008
# Numero_victimes                816
# Nom_carrer                       2
# Numero_expedient                 0
# Codi_districte                   0
# Hora_dia                         0
# Descripcio_torn                  0
# Descripcio_dia_setmana           0
# Nom_districte                    0
# Codi_carrer                      0
# Dia_mes                          0
# Nom_mes                          0
# Mes_any                          0
# Nom_barri                        0
# Codi_barri                       0
# Numero_vehicles_implicats        0
# dtype: int64

# %%
df_accidents.describe().T
# Out:
#                              count           mean            std          min  \
# Codi_districte             67488.0       4.868243       3.013772    -1.000000
# Codi_carrer                67488.0  247783.118169  200040.713513    -1.000000
# Any                        20275.0    2017.490062       0.499914  2017.000000
# Mes_any                    67488.0       6.534554       3.462213     1.000000
# Dia_mes                    67488.0      15.717150       8.779916     1.000000
# Hora_dia                   67488.0      13.828266       5.320445     0.000000
# Numero_morts               59963.0       0.002285       0.047745     0.000000
# Numero_lesionats_lleus     66480.0       1.153309       0.754789     0.000000
# Numero_lesionats_greus     60193.0       0.027345       0.175739     0.000000
# Numero_victimes            66672.0       1.176731       0.749221     0.000000
# Numero_vehicles_implicats  67488.0       1.886898       0.717799     0.000000
# Longitud                   44569.0       3.128052      45.621050    -1.488576
# Latitud                    44569.0      59.934192     875.557565     0.000009
# NK_Any                     47213.0    2021.417957       1.751577  2019.000000
# Longitud_WGS84             22895.0       2.162846       0.024417     2.058047
# Latitud_WGS84              22895.0      41.400521       0.022460    41.322721
#
#                                      25%            50%            75%  \
# Codi_districte                  2.000000       4.000000       7.000000
# Codi_carrer                115400.000000  191204.000000  320908.000000
# Any                          2017.000000    2017.000000    2018.000000
# Mes_any                         4.000000       7.000000      10.000000
# Dia_mes                         8.000000      16.000000      23.000000
# Hora_dia                       10.000000      14.000000      18.000000
# Numero_morts                    0.000000       0.000000       0.000000
# Numero_lesionats_lleus          1.000000       1.000000       1.000000
# Numero_lesionats_greus          0.000000       0.000000       0.000000
# Numero_victimes                 1.000000       1.000000       1.000000
# Numero_vehicles_implicats       2.000000       2.000000       2.000000
# Longitud                        2.145109       2.163811       2.180220
# Latitud                        41.385887      41.397111      41.411475
# NK_Any                       2020.000000    2021.000000    2023.000000
# Longitud_WGS84                  2.144797       2.163447       2.180530
# Latitud_WGS84                  41.385918      41.397848      41.413622
#
#                                      max
# Codi_districte                 10.000000
# Codi_carrer                701918.000000
# Any                          2018.000000
# Mes_any                        12.000000
# Dia_mes                        31.000000
# Hora_dia                       23.000000
# Numero_morts                    1.000000
# Numero_lesionats_lleus         25.000000
# Numero_lesionats_greus          6.000000
# Numero_victimes                26.000000
# Numero_vehicles_implicats      18.000000
# Longitud                     2188.000000
# Latitud                     41414.000000
# NK_Any                       2024.000000
# Longitud_WGS84                  2.223673
# Latitud_WGS84                  41.467466

# %%
df_accidents['Dia_setmana'].value_counts()
# Out:
# Dia_setmana
# Dv    5122
# Dj    4923
# Dc    4915
# Dm    4879
# Dl    4530
# Ds    3338
# Dg    2595
# 4     1104
# 5     1032
# 3     1023
# 1      972
# 2      933
# 6      686
# 7      518
# Name: count, dtype: int64

# %%
# Ver si hay valores duplicados del numero de expediente
duplicados = df_accidents[df_accidents["Numero_expedient"].duplicated()]
duplicados
# Out:
#       Numero_expedient  Codi_districte        Nom_districte Codi_barri  \
# 5800   2017S003286                   3       Sants-Montjuïc         13
# 6492   2017S008856                  10           Sant Martí         71
# 6979   2017S003750                   2             Eixample          7
# 9211   2017S004447                  10           Sant Martí         69
# 10655  2018S003156                   3       Sants-Montjuïc         16
# 10784  2018S002285                   3       Sants-Montjuïc         16
# 11548  2018S002968                   3       Sants-Montjuïc         17
# 11591  2018S009504                   2             Eixample         10
# 12870  2018S005992                   1         Ciutat Vella          4
# 13124  2018S001774                   4            Les Corts         20
# 14651  2018S000261                   5  Sarrià-Sant Gervasi         23
# 16010  2018S002344                   5  Sarrià-Sant Gervasi         26
# 17263  2018S001500                   6               Gràcia         31
# 17379  2018S000183                   6               Gràcia         32
# 30935  2020S000638                   5  Sarrià-Sant Gervasi    51-5-26
# 31076  2020S000778                   9          Sant Andreu    91-9-63
# 31253  2020S000956                   2             Eixample     23-2-8
# 33958  2020S003665                   2             Eixample     25-2-6
# 34772  2020S004479                   5  Sarrià-Sant Gervasi    53-5-25
# 34883  2020S004590                   8           Nou Barris    82-8-49
# 35587  2020S005294                   4            Les Corts    42-4-20
# 39132  2021S000395                   6               Gràcia         28
# 39836  2021S000847                   2             Eixample          6
# 42346  2021S001332                  10           Sant Martí         64
# 42627  2021S002982                   2             Eixample          8
# 43329  2021S001951                  10           Sant Martí         65
# 43982  2021S005130                   6               Gràcia         28
# 45517  2022S000750                   2             Eixample          7
# 48105  2022S000364                   7       Horta-Guinardó         33
# 48476  2022S007820                   2             Eixample          8
# 49388  2022S001333                   1         Ciutat Vella          1
# 49507  2022S002608                   2             Eixample          9
# 49527  2022S007071                   2             Eixample          9
# 50367  2022S003249                  10           Sant Martí         71
# 50627  2022S000411                   2             Eixample          6
# 50717  2022S007743                   2             Eixample          5
# 51395  2022S000209                   1         Ciutat Vella          2
# 53302  2023S001079                   6               Gràcia         31
# 56937  2023S004724                  10           Sant Martí         67
# 59066  2023S006857                   2             Eixample         10
#
#                                           Nom_barri  Codi_carrer  \
# 5800                              la Marina de Port       109906
# 6492                        Provençals del Poblenou        30409
# 6979                         la Dreta de l'Eixample       357001
# 9211   Diagonal Mar i el Front Marítim del Poblenou       701278
# 10655                                    la Bordeta       169409
# 10784                                    la Bordeta        89707
# 11548                                 Sants - Badal       187207
# 11591                                   Sant Antoni       127704
# 12870         Sant Pere, Santa Caterina i la Ribera       177101
# 13124                    la Maternitat i Sant Ramon       144601
# 14651                                        Sarrià       305201
# 16010                        Sant Gervasi - Galvany       143904
# 17263                             la Vila de Gràcia       290206
# 17379            el Camp d'en Grassot i Gràcia Nova       356304
# 30935                        Sant Gervasi - Galvany       344101
# 31076                                         Navas       209900
# 31253               l'Antiga Esquerra de l'Eixample       350308
# 33958                            la Sagrada Família       178308
# 34772                    Sant Gervasi - la Bonanova       701268
# 34883                                     Canyelles       120807
# 35587                    la Maternitat i Sant Ramon       187207
# 39132                     Vallcarca i els Penitents       123408
# 39836                            la Sagrada Família        90502
# 42346                    el Camp de l'Arpa del Clot       161407
# 42627               l'Antiga Esquerra de l'Eixample       169409
# 43329                                       el Clot       161101
# 43982                     Vallcarca i els Penitents       158107
# 45517                        la Dreta de l'Eixample       169409
# 48105                              el Baix Guinardó        76807
# 48476               l'Antiga Esquerra de l'Eixample       349706
# 49388                                      el Raval        76501
# 49507                la Nova Esquerra de l'Eixample       350308
# 49527                la Nova Esquerra de l'Eixample        54509
# 50367                       Provençals del Poblenou       169409
# 50627                            la Sagrada Família        68900
# 50717                                 el Fort Pienc       197302
# 51395                                el Barri Gòtic        82901
# 53302                             la Vila de Gràcia       267000
# 56937                 la Vila Olímpica del Poblenou       110009
# 59066                                   Sant Antoni       323203
#
#                                               Nom_carrer  Num_postal  \
# 5800   Energia                                       ...  0001X0001X
# 6492   Diagonal / Bac de Roda                        ...   0100 0108
# 6979   Bergara                                       ...   0014 0014
# 9211   Taulat                                        ...   0136 0136
# 10655  Corts Catalanes                               ...         NaN
# 10784  Constitució                                   ...         NaN
# 11548  Madrid                                        ...         NaN
# 11591  Floridablanca / Viladomat                     ...         NaN
# 12870  Laietana                                      ...         NaN
# 13124  Diagonal                                      ...         NaN
# 14651  Sant Joan Bosco / Maria Auxiliadora           ...         NaN
# 16010  General Mitre                                 ...         NaN
# 17263  Torrent de les Flors / Rovira i Trias         ...         NaN
# 17379  Taxdirt / Ventalló                            ...         NaN
# 30935                                             Gràcia         NaN
# 31076                                          Meridiana         NaN
# 31253                                           València         NaN
# 33958                                             Lepant         NaN
# 34772                                   Dalt (Llobregat)         NaN
# 34883                                           Favència         NaN
# 35587                                             Madrid         NaN
# 39132                                            Lesseps         NaN
# 39836                                            Còrsega         NaN
# 42346                                          Indústria         NaN
# 42627                                    Corts Catalanes         NaN
# 43329                                      Independència         NaN
# 43982                                          Vallcarca         NaN
# 45517  Corts Catalanes                               ...         NaN
# 48105  Sardenya / Providència                        ...         NaN
# 48476  Comte d'Urgell / Sarrià                       ...         NaN
# 49388  Cera / Reina Amàlia                           ...         NaN
# 49507  València                                      ...         NaN
# 49527  Calàbria / Diputació                          ...         NaN
# 50367  Corts Catalanes                               ...         NaN
# 50627  Cartagena                                     ...         NaN
# 50717  Marina                                        ...         NaN
# 51395  Colom                                         ...         NaN
# 53302  Riera de Cassoles / Bretón de los Herreros    ...         NaN
# 56937  Ramon Turró                                   ...         NaN
# 59066  Sepúlveda                                     ...         NaN
#
#       Descripcio_dia_setmana Dia_setmana  ... Coordenada_UTM_Y  Longitud  \
# 5800                 Dilluns          Dl  ...        4579006,9  2.136744
# 6492                  Dijous          Dj  ...       4584557,54  2.203962
# 6979                  Dijous          Dj  ...       4582179,48  2.168836
# 9211               Divendres          Dv  ...       4583913,96  2.209813
# 10655                Dimarts          Dm  ...       4579751.39  2.133801
# 10784                 Dijous          Dj  ...       4580251.36  2.132499
# 11548               Dimecres          Dc  ...       4581285.13  2.126816
# 11591                 Dijous          Dj  ...       4581335.47  2.158684
# 12870                 Dijous          Dj  ...       4582187.93  2.175646
# 13124               Diumenge          Dg  ...       4582337.48  2.125516
# 14651                 Dijous          Dj  ...       4583076.17  2.127990
# 16010               Dissabte          Ds  ...       4583745.01  2.135246
# 17263               Dissabte          Ds  ...       4584552.91  2.158799
# 17379                Dilluns          Dl  ...       4584642.04  2.164942
# 30935                Dilluns           1  ...        4583295.6  2.149556
# 31076                 Dijous           4  ...        4585841.6  2.186612
# 31253               Dissabte           6  ...       4582643.19  2.160104
# 33958                 Dijous           4  ...       4584077.09  2.178158
# 34772                Dimarts           2  ...       4585391.51  2.136151
# 34883                 Dijous           4  ...       4588348.41  2.166402
# 35587               Dimecres           3  ...        4581210.7  2.125031
# 39132                Dimarts         NaN  ...              NaN       NaN
# 39836                 Dijous         NaN  ...              NaN       NaN
# 42346                Dimarts         NaN  ...              NaN       NaN
# 42627               Dissabte         NaN  ...              NaN       NaN
# 43329                 Dijous         NaN  ...              NaN       NaN
# 43982                 Dijous         NaN  ...              NaN       NaN
# 45517                Dimarts         NaN  ...              NaN  2.165224
# 48105               Dissabte         NaN  ...              NaN  2.163939
# 48476               Dimecres         NaN  ...              NaN  2.148272
# 49388               Dissabte         NaN  ...              NaN  2.165245
# 49507                Dimarts         NaN  ...              NaN  2.148623
# 49527              Divendres         NaN  ...              NaN  2.153920
# 50367               Dissabte         NaN  ...              NaN  2.204231
# 50627                Dilluns         NaN  ...              NaN  2.178533
# 50717              Divendres         NaN  ...              NaN  2.179451
# 51395              Divendres         NaN  ...              NaN  2.181484
# 53302               Dimecres         NaN  ...              NaN       NaN
# 56937              Divendres         NaN  ...              NaN       NaN
# 59066               Dissabte         NaN  ...              NaN       NaN
#
#          Latitud Num_postal   Num_postal_caption  NK_Any  \
# 5800   41.357598         NaN                 NaN     NaN
# 6492   41.407568         NaN                 NaN     NaN
# 6979   41.386306         NaN                 NaN     NaN
# 9211   41.402218         NaN                 NaN     NaN
# 10655  41.364177  111-119                    NaN     NaN
# 10784  41.368671         155                 NaN     NaN
# 11548  41.377939          68                 NaN     NaN
# 11591  41.378630         NaN                 NaN     NaN
# 12870  41.386431          46                 NaN     NaN
# 13124  41.387409         629                 NaN     NaN
# 14651  41.394081         NaN                 NaN     NaN
# 16010  41.400160  92-94                      NaN     NaN
# 17263  41.407612         NaN                 NaN     NaN
# 17379  41.408460         NaN                 NaN     NaN
# 30935  41.396216         NaN           0051 0051  2020.0
# 31076  41.419417         NaN           0235 0235  2020.0
# 31253  41.390417         NaN           0211 0211  2020.0
# 33958  41.403463         NaN           0258 0258  2020.0
# 34772  41.414995         NaN              940000  2020.0
# 34883  41.441853         NaN           0041 0045  2020.0
# 35587  41.377253         NaN           0039 0041  2020.0
# 39132        NaN         NaN          0021X0021X  2021.0
# 39836        NaN         NaN           0532 0532  2021.0
# 42346        NaN         NaN           0279 0281  2021.0
# 42627        NaN         NaN           0583 0583  2021.0
# 43329        NaN         NaN           0243 0243  2021.0
# 43982        NaN         NaN           0133 0147  2021.0
# 45517  41.386804         NaN           0602 0602  2022.0
# 48105  41.410488         NaN           0494 0494  2022.0
# 48476  41.389882         NaN           0217 0223  2022.0
# 49388  41.378098         NaN           0040 0040  2022.0
# 49507  41.381494         NaN           0064 0066  2022.0
# 49527  41.380520         NaN           0115 0117  2022.0
# 50367  41.415753         NaN           1092 1094  2022.0
# 50627  41.407851         NaN           0241 0241  2022.0
# 50717  41.400151         NaN           0191 0191  2022.0
# 51395  41.381019         NaN           0001 0001  2022.0
# 53302        NaN   0008 0008                 NaN  2023.0
# 56937        NaN   0037 0037                 NaN  2023.0
# 59066        NaN   0096 0096                 NaN  2023.0
#
#       Coordenada_UTM_X_ED50 Coordenada_UTM_Y_ED50  Longitud_WGS84  \
# 5800                    NaN                   NaN             NaN
# 6492                    NaN                   NaN             NaN
# 6979                    NaN                   NaN             NaN
# 9211                    NaN                   NaN             NaN
# 10655                   NaN                   NaN             NaN
# 10784                   NaN                   NaN             NaN
# 11548                   NaN                   NaN             NaN
# 11591                   NaN                   NaN             NaN
# 12870                   NaN                   NaN             NaN
# 13124                   NaN                   NaN             NaN
# 14651                   NaN                   NaN             NaN
# 16010                   NaN                   NaN             NaN
# 17263                   NaN                   NaN             NaN
# 17379                   NaN                   NaN             NaN
# 30935                   NaN                   NaN             NaN
# 31076                   NaN                   NaN             NaN
# 31253                   NaN                   NaN             NaN
# 33958                   NaN                   NaN             NaN
# 34772                   NaN                   NaN             NaN
# 34883                   NaN                   NaN             NaN
# 35587                   NaN                   NaN             NaN
# 39132             429024.35            4584481.54        2.149706
# 39836             430891.22             4584360.4        2.172053
# 42346             431670.92            4585357.49        2.181268
# 42627             430080.36            4582095.48        2.162615
# 43329             432003.59            4584366.47        2.185360
# 43982              428461.6            4585247.52        2.142883
# 45517             430299.85            4582237.63             NaN
# 48105             430217.78            4584868.03             NaN
# 48476             428885.89            4582593.13             NaN
# 49388             430292.31            4581271.11             NaN
# 49507             428906.06            4581661.62             NaN
# 49527             429347.93             4581549.1             NaN
# 50367             433590.68            4585420.82             NaN
# 50627             431434.74            4584563.62             NaN
# 50717             431503.37            4583708.04             NaN
# 51395             431653.31            4581582.41             NaN
# 53302            4583923.03            429116.73         2.150877
# 56937            4582848.16            432648.07         2.193239
# 59066            4581394.65            429629.64         2.157306
#
#        Latitud_WGS84
# 5800             NaN
# 6492             NaN
# 6979             NaN
# 9211             NaN
# 10655            NaN
# 10784            NaN
# 11548            NaN
# 11591            NaN
# 12870            NaN
# 13124            NaN
# 14651            NaN
# 16010            NaN
# 17263            NaN
# 17379            NaN
# 30935            NaN
# 31076            NaN
# 31253            NaN
# 33958            NaN
# 34772            NaN
# 34883            NaN
# 35587            NaN
# 39132      41.406900
# 39836      41.405971
# 42346      41.415019
# 42627      41.385502
# 43329      41.406121
# 43982      41.413749
# 45517            NaN
# 48105            NaN
# 48476            NaN
# 49388            NaN
# 49507            NaN
# 49527            NaN
# 50367            NaN
# 50627            NaN
# 50717            NaN
# 51395            NaN
# 53302      41.401878
# 56937      41.392500
# 59066      41.379150
#
# [40 rows x 34 columns]

# %%
# Encontrar los expedientes duplicados (que aparecen más de una vez)
duplicados_ids = df_accidents["Numero_expedient"][df_accidents["Numero_expedient"].duplicated(keep=False)]
duplicados_ids
# Out:
# 84       2017S008856
# 3079     2017S003750
# 5222     2017S004447
# 5799     2017S003286
# 5800     2017S003286
#               ...
# 53302    2023S001079
# 56936    2023S004724
# 56937    2023S004724
# 59065    2023S006857
# 59066    2023S006857
# Name: Numero_expedient, Length: 80, dtype: object

# %%
# Filtrar todos los registros con los expedientes duplicados
expedientes_duplicados= df_accidents[df_accidents["Numero_expedient"].isin(duplicados_ids)]
expedientes_duplicados.sort_values("Numero_expedient")
# Out:
#       Numero_expedient  Codi_districte   Nom_districte Codi_barri  \
# 5799   2017S003286                   3  Sants-Montjuïc         13
# 5800   2017S003286                   3  Sants-Montjuïc         13
# 3079   2017S003750                   2        Eixample          7
# 6979   2017S003750                   2        Eixample          7
# 5222   2017S004447                  10      Sant Martí         69
# ...                ...             ...             ...        ...
# 53302  2023S001079                   6          Gràcia         31
# 56936  2023S004724                  10      Sant Martí         67
# 56937  2023S004724                  10      Sant Martí         67
# 59065  2023S006857                   2        Eixample         10
# 59066  2023S006857                   2        Eixample         10
#
#                                           Nom_barri  Codi_carrer  \
# 5799                              la Marina de Port       109906
# 5800                              la Marina de Port       109906
# 3079                         la Dreta de l'Eixample       357001
# 6979                         la Dreta de l'Eixample       357001
# 5222   Diagonal Mar i el Front Marítim del Poblenou       701278
# ...                                             ...          ...
# 53302                             la Vila de Gràcia       267000
# 56936                 la Vila Olímpica del Poblenou       110009
# 56937                 la Vila Olímpica del Poblenou       110009
# 59065                                   Sant Antoni       323203
# 59066                                   Sant Antoni       323203
#
#                                               Nom_carrer  Num_postal  \
# 5799   Energia                                       ...  0001X0001X
# 5800   Energia                                       ...  0001X0001X
# 3079   Bergara                                       ...   0014 0014
# 6979   Bergara                                       ...   0014 0014
# 5222   Taulat                                        ...   0136 0136
# ...                                                  ...         ...
# 53302  Riera de Cassoles / Bretón de los Herreros    ...         NaN
# 56936  Ramon Turró                                   ...         NaN
# 56937  Ramon Turró                                   ...         NaN
# 59065  Sepúlveda                                     ...         NaN
# 59066  Sepúlveda                                     ...         NaN
#
#       Descripcio_dia_setmana Dia_setmana  ... Coordenada_UTM_Y  Longitud  \
# 5799                 Dilluns          Dl  ...        4579006,9  2.136744
# 5800                 Dilluns          Dl  ...        4579006,9  2.136744
# 3079                  Dijous          Dj  ...       4582179,48  2.168836
# 6979                  Dijous          Dj  ...       4582179,48  2.168836
# 5222               Divendres          Dv  ...       4583913,96  2.209813
# ...                      ...         ...  ...              ...       ...
# 53302               Dimecres         NaN  ...              NaN       NaN
# 56936              Divendres         NaN  ...              NaN       NaN
# 56937              Divendres         NaN  ...              NaN       NaN
# 59065               Dissabte         NaN  ...              NaN       NaN
# 59066               Dissabte         NaN  ...              NaN       NaN
#
#          Latitud Num_postal   Num_postal_caption  NK_Any  \
# 5799   41.357598         NaN                 NaN     NaN
# 5800   41.357598         NaN                 NaN     NaN
# 3079   41.386306         NaN                 NaN     NaN
# 6979   41.386306         NaN                 NaN     NaN
# 5222   41.402218         NaN                 NaN     NaN
# ...          ...         ...                 ...     ...
# 53302        NaN   0008 0008                 NaN  2023.0
# 56936        NaN   0037 0037                 NaN  2023.0
# 56937        NaN   0037 0037                 NaN  2023.0
# 59065        NaN   0096 0096                 NaN  2023.0
# 59066        NaN   0096 0096                 NaN  2023.0
#
#       Coordenada_UTM_X_ED50 Coordenada_UTM_Y_ED50  Longitud_WGS84  \
# 5799                    NaN                   NaN             NaN
# 5800                    NaN                   NaN             NaN
# 3079                    NaN                   NaN             NaN
# 6979                    NaN                   NaN             NaN
# 5222                    NaN                   NaN             NaN
# ...                     ...                   ...             ...
# 53302            4583923.03            429116.73         2.150877
# 56936            4582848.16            432648.07         2.193239
# 56937            4582848.16            432648.07         2.193239
# 59065            4581394.65            429629.64         2.157306
# 59066            4581394.65            429629.64         2.157306
#
#        Latitud_WGS84
# 5799             NaN
# 5800             NaN
# 3079             NaN
# 6979             NaN
# 5222             NaN
# ...              ...
# 53302      41.401878
# 56936      41.392500
# 56937      41.392500
# 59065      41.379150
# 59066      41.379150
#
# [80 rows x 34 columns]

# %%
col_fijas = [c for c in df_accidents.columns if c != 'Descripcio_causa_vianant']

df_accidents = (
    df_accidents
    .groupby("Numero_expedient", as_index=False)
    .agg({
        **{col: 'first' for col in col_fijas if col != "Numero_expedient"},
        'Descripcio_causa_vianant': lambda x: (
            pd.NA if x.isna().all() 
            else ", ".join(sorted(set(v for v in x if pd.notna(v) and str(v).strip() != "")))
        )
    })
)

# %%
df_accidents
# Out:
#       Numero_expedient  Codi_districte        Nom_districte Codi_barri  \
# 0      2017S000001                   5  Sarrià-Sant Gervasi         26
# 1      2017S000002                   2             Eixample          5
# 2      2017S000003                   7       Horta-Guinardó         33
# 3      2017S000004                   2             Eixample          6
# 4      2017S000005                  10           Sant Martí         66
# ...                ...             ...                  ...        ...
# 67443      2024S007547               2             Eixample          7
# 67444      2024S007548               1         Ciutat Vella          4
# 67445      2024S007549               3       Sants-Montjuïc         11
# 67446      2024S007550               3       Sants-Montjuïc         11
# 67447      2024S007551               1         Ciutat Vella          1
#
#                                    Nom_barri  Codi_carrer  \
# 0                     Sant Gervasi - Galvany       187105
# 1                              el Fort Pienc       197302
# 2                           el Baix Guinardó       265402
# 3                         la Sagrada Família        89004
# 4          el Parc i la Llacuna del Poblenou       243206
# ...                                      ...          ...
# 67443                 la Dreta de l'Eixample       169409
# 67444  Sant Pere, Santa Caterina i la Ribera       143100
# 67445                           el Poble Sec       198804
# 67446                           el Poble Sec       234001
# 67447                               el Raval       701367
#
#                                               Nom_carrer Num_postal  \
# 0      VIA AUGUSTA                                   ...  0063 0063
# 1      GV CORTS CATALANES                            ...  0120 0120
# 2      RDA GUINARDÓ                                  ...  0000 0000
# 3      BALMES / Rosselló                             ...  0531 0531
# 4      PALLARS                                       ...  0091 0091
# ...                                                  ...        ...
# 67443                                    Corts Catalanes       None
# 67444                          General Álvarez de Castro       None
# 67445                                          Paral·lel       None
# 67446                                            Olímpic       None
# 67447                                              Raval       None
#
#       Descripcio_dia_setmana Dia_setmana  ...  Longitud    Latitud  \
# 0                   Diumenge          Dg  ...  2.151330  41.400771
# 1                   Diumenge          Dg  ...  2.182376  41.399680
# 2                   Diumenge          Dg  ...  2.166464  41.412769
# 3                   Diumenge          Dg  ...  2.157359  41.393310
# 4                   Diumenge          Dg  ...  2.193249  41.397908
# ...                      ...         ...  ...       ...        ...
# 67443                Dimarts        None  ...       NaN        NaN
# 67444               Dissabte        None  ...       NaN        NaN
# 67445                 Dijous        None  ...       NaN        NaN
# 67446                Dilluns        None  ...       NaN        NaN
# 67447              Divendres        None  ...       NaN        NaN
#
#        Num_postal  Num_postal_caption  NK_Any  Coordenada_UTM_X_ED50  \
# 0             None               None     NaN                   None
# 1             None               None     NaN                   None
# 2             None               None     NaN                   None
# 3             None               None     NaN                   None
# 4             None               None     NaN                   None
# ...            ...                ...     ...                    ...
# 67443          603               None  2024.0            4582460.824
# 67444          2-4               None  2024.0            4582233.737
# 67445         None               None  2024.0             4580940.29
# 67446          1-3               None  2024.0            4579426.054
# 67447          25X               None  2024.0            4581341.695
#
#       Coordenada_UTM_Y_ED50  Longitud_WGS84  Latitud_WGS84  \
# 0                      None             NaN            NaN
# 1                      None             NaN            NaN
# 2                      None             NaN            NaN
# 3                      None             NaN            NaN
# 4                      None             NaN            NaN
# ...                     ...             ...            ...
# 67443            430450.705        2.167002      41.388825
# 67444            431382.242        2.178169      41.386859
# 67445            428989.313        2.149703      41.375002
# 67446            429206.725        2.152479      41.361383
# 67447            430668.432        2.169734      41.378764
#
#        Descripcio_causa_vianant
# 0      No és causa del  vianant
# 1      No és causa del  vianant
# 2      No és causa del  vianant
# 3      No és causa del  vianant
# 4      No és causa del  vianant
# ...                         ...
# 67443                    Altres
# 67444                      <NA>
# 67445                      <NA>
# 67446                      <NA>
# 67447                      <NA>
#
# [67448 rows x 34 columns]

# %%
# Comprobamos que ya no hay expedientes duplicados
df_accidents[df_accidents["Numero_expedient"].isin(duplicados_ids)]
# Out:
#       Numero_expedient  Codi_districte        Nom_districte Codi_barri  \
# 2887   2017S003286                   3       Sants-Montjuïc         13
# 3348   2017S003750                   2             Eixample          7
# 4041   2017S004447                  10           Sant Martí         69
# 8413   2017S008856                  10           Sant Martí         71
# 10517  2018S000183                   6               Gràcia         32
# 10594  2018S000261                   5  Sarrià-Sant Gervasi         23
# 11819  2018S001500                   6               Gràcia         31
# 12093  2018S001774                   4            Les Corts         20
# 12602  2018S002285                   3       Sants-Montjuïc         16
# 12660  2018S002344                   5  Sarrià-Sant Gervasi         26
# 13282  2018S002968                   3       Sants-Montjuïc         17
# 13467  2018S003156                   3       Sants-Montjuïc         16
# 16288  2018S005992                   1         Ciutat Vella          4
# 19792  2018S009504                   2             Eixample         10
# 30920  2020S000638                   5  Sarrià-Sant Gervasi    51-5-26
# 31060  2020S000778                   9          Sant Andreu    91-9-63
# 31236  2020S000956                   2             Eixample     23-2-8
# 33940  2020S003665                   2             Eixample     25-2-6
# 34753  2020S004479                   5  Sarrià-Sant Gervasi    53-5-25
# 34863  2020S004590                   8           Nou Barris    82-8-49
# 35566  2020S005294                   4            Les Corts    42-4-20
# 36943  2021S000395                   6               Gràcia         28
# 37394  2021S000847                   2             Eixample          6
# 37879  2021S001332                  10           Sant Martí         64
# 38495  2021S001951                  10           Sant Martí         65
# 39522  2021S002982                   2             Eixample          8
# 41668  2021S005130                   6               Gràcia         28
# 44410  2022S000209                   1         Ciutat Vella          2
# 44564  2022S000364                   7       Horta-Guinardó         33
# 44611  2022S000411                   2             Eixample          6
# 44949  2022S000750                   2             Eixample          7
# 45528  2022S001333                   1         Ciutat Vella          1
# 46801  2022S002608                   2             Eixample          9
# 47440  2022S003249                  10           Sant Martí         71
# 51252  2022S007071                   2             Eixample          9
# 51919  2022S007743                   2             Eixample          5
# 51995  2022S007820                   2             Eixample          8
# 53264  2023S001079                   6               Gràcia         31
# 56898  2023S004724                  10           Sant Martí         67
# 59026  2023S006857                   2             Eixample         10
#
#                                           Nom_barri  Codi_carrer  \
# 2887                              la Marina de Port       109906
# 3348                         la Dreta de l'Eixample       357001
# 4041   Diagonal Mar i el Front Marítim del Poblenou       701278
# 8413                        Provençals del Poblenou        30409
# 10517            el Camp d'en Grassot i Gràcia Nova       356304
# 10594                                        Sarrià       305201
# 11819                             la Vila de Gràcia       290206
# 12093                    la Maternitat i Sant Ramon       144601
# 12602                                    la Bordeta        89707
# 12660                        Sant Gervasi - Galvany       143904
# 13282                                 Sants - Badal       187207
# 13467                                    la Bordeta       169409
# 16288         Sant Pere, Santa Caterina i la Ribera       177101
# 19792                                   Sant Antoni       127704
# 30920                        Sant Gervasi - Galvany       344101
# 31060                                         Navas       209900
# 31236               l'Antiga Esquerra de l'Eixample       350308
# 33940                            la Sagrada Família       178308
# 34753                    Sant Gervasi - la Bonanova       701268
# 34863                                     Canyelles       120807
# 35566                    la Maternitat i Sant Ramon       187207
# 36943                     Vallcarca i els Penitents       123408
# 37394                            la Sagrada Família        90502
# 37879                    el Camp de l'Arpa del Clot       161407
# 38495                                       el Clot       161101
# 39522               l'Antiga Esquerra de l'Eixample       169409
# 41668                     Vallcarca i els Penitents       158107
# 44410                                el Barri Gòtic        82901
# 44564                              el Baix Guinardó        76807
# 44611                            la Sagrada Família        68900
# 44949                        la Dreta de l'Eixample       169409
# 45528                                      el Raval        76501
# 46801                la Nova Esquerra de l'Eixample       350308
# 47440                       Provençals del Poblenou       169409
# 51252                la Nova Esquerra de l'Eixample        54509
# 51919                                 el Fort Pienc       197302
# 51995               l'Antiga Esquerra de l'Eixample       349706
# 53264                             la Vila de Gràcia       267000
# 56898                 la Vila Olímpica del Poblenou       110009
# 59026                                   Sant Antoni       323203
#
#                                               Nom_carrer  Num_postal  \
# 2887   Energia                                       ...  0001X0001X
# 3348   Bergara                                       ...   0014 0014
# 4041   Taulat                                        ...   0136 0136
# 8413   Diagonal / Bac de Roda                        ...   0100 0108
# 10517  Taxdirt / Ventalló                            ...        None
# 10594  Sant Joan Bosco / Maria Auxiliadora           ...        None
# 11819  Torrent de les Flors / Rovira i Trias         ...        None
# 12093  Diagonal                                      ...        None
# 12602  Constitució                                   ...        None
# 12660  General Mitre                                 ...        None
# 13282  Madrid                                        ...        None
# 13467  Corts Catalanes                               ...        None
# 16288  Laietana                                      ...        None
# 19792  Floridablanca / Viladomat                     ...        None
# 30920                                             Gràcia        None
# 31060                                          Meridiana        None
# 31236                                           València        None
# 33940                                             Lepant        None
# 34753                                   Dalt (Llobregat)        None
# 34863                                           Favència        None
# 35566                                             Madrid        None
# 36943                                            Lesseps        None
# 37394                                            Còrsega        None
# 37879                                          Indústria        None
# 38495                                      Independència        None
# 39522                                    Corts Catalanes        None
# 41668                                          Vallcarca        None
# 44410  Colom                                         ...        None
# 44564  Sardenya / Providència                        ...        None
# 44611  Cartagena                                     ...        None
# 44949  Corts Catalanes                               ...        None
# 45528  Cera / Reina Amàlia                           ...        None
# 46801  València                                      ...        None
# 47440  Corts Catalanes                               ...        None
# 51252  Calàbria / Diputació                          ...        None
# 51919  Marina                                        ...        None
# 51995  Comte d'Urgell / Sarrià                       ...        None
# 53264  Riera de Cassoles / Bretón de los Herreros    ...        None
# 56898  Ramon Turró                                   ...        None
# 59026  Sepúlveda                                     ...        None
#
#       Descripcio_dia_setmana Dia_setmana  ...  Longitud    Latitud  \
# 2887                 Dilluns          Dl  ...  2.136744  41.357598
# 3348                  Dijous          Dj  ...  2.168836  41.386306
# 4041               Divendres          Dv  ...  2.209813  41.402218
# 8413                  Dijous          Dj  ...  2.203962  41.407568
# 10517                Dilluns          Dl  ...  2.164942  41.408460
# 10594                 Dijous          Dj  ...  2.127990  41.394081
# 11819               Dissabte          Ds  ...  2.158799  41.407612
# 12093               Diumenge          Dg  ...  2.125516  41.387409
# 12602                 Dijous          Dj  ...  2.132499  41.368671
# 12660               Dissabte          Ds  ...  2.135246  41.400160
# 13282               Dimecres          Dc  ...  2.126816  41.377939
# 13467                Dimarts          Dm  ...  2.133801  41.364177
# 16288                 Dijous          Dj  ...  2.175646  41.386431
# 19792                 Dijous          Dj  ...  2.158684  41.378630
# 30920                Dilluns           1  ...  2.149556  41.396216
# 31060                 Dijous           4  ...  2.186612  41.419417
# 31236               Dissabte           6  ...  2.160104  41.390417
# 33940                 Dijous           4  ...  2.178158  41.403463
# 34753                Dimarts           2  ...  2.136151  41.414995
# 34863                 Dijous           4  ...  2.166402  41.441853
# 35566               Dimecres           3  ...  2.125031  41.377253
# 36943                Dimarts        None  ...       NaN        NaN
# 37394                 Dijous        None  ...       NaN        NaN
# 37879                Dimarts        None  ...       NaN        NaN
# 38495                 Dijous        None  ...       NaN        NaN
# 39522               Dissabte        None  ...       NaN        NaN
# 41668                 Dijous        None  ...       NaN        NaN
# 44410              Divendres        None  ...  2.181484  41.381019
# 44564               Dissabte        None  ...  2.163939  41.410488
# 44611                Dilluns        None  ...  2.178533  41.407851
# 44949                Dimarts        None  ...  2.165224  41.386804
# 45528               Dissabte        None  ...  2.165245  41.378098
# 46801                Dimarts        None  ...  2.148623  41.381494
# 47440               Dissabte        None  ...  2.204231  41.415753
# 51252              Divendres        None  ...  2.153920  41.380520
# 51919              Divendres        None  ...  2.179451  41.400151
# 51995               Dimecres        None  ...  2.148272  41.389882
# 53264               Dimecres        None  ...       NaN        NaN
# 56898              Divendres        None  ...       NaN        NaN
# 59026               Dissabte        None  ...       NaN        NaN
#
#        Num_postal  Num_postal_caption  NK_Any  Coordenada_UTM_X_ED50  \
# 2887          None               None     NaN                   None
# 3348          None               None     NaN                   None
# 4041          None               None     NaN                   None
# 8413          None               None     NaN                   None
# 10517         None               None     NaN                   None
# 10594         None               None     NaN                   None
# 11819         None               None     NaN                   None
# 12093          629               None     NaN                   None
# 12602          155               None     NaN                   None
# 12660   92-94                    None     NaN                   None
# 13282           68               None     NaN                   None
# 13467   111-119                  None     NaN                   None
# 16288           46               None     NaN                   None
# 19792         None               None     NaN                   None
# 30920         None          0051 0051  2020.0                   None
# 31060         None          0235 0235  2020.0                   None
# 31236         None          0211 0211  2020.0                   None
# 33940         None          0258 0258  2020.0                   None
# 34753         None             940000  2020.0                   None
# 34863         None          0041 0045  2020.0                   None
# 35566         None          0039 0041  2020.0                   None
# 36943         None         0021X0021X  2021.0              429024.35
# 37394         None          0532 0532  2021.0              430891.22
# 37879         None          0279 0281  2021.0              431670.92
# 38495         None          0243 0243  2021.0              432003.59
# 39522         None          0583 0583  2021.0              430080.36
# 41668         None          0133 0147  2021.0               428461.6
# 44410         None          0001 0001  2022.0              431653.31
# 44564         None          0494 0494  2022.0              430217.78
# 44611         None          0241 0241  2022.0              431434.74
# 44949         None          0602 0602  2022.0              430299.85
# 45528         None          0040 0040  2022.0              430292.31
# 46801         None          0064 0066  2022.0              428906.06
# 47440         None          1092 1094  2022.0              433590.68
# 51252         None          0115 0117  2022.0              429347.93
# 51919         None          0191 0191  2022.0              431503.37
# 51995         None          0217 0223  2022.0              428885.89
# 53264    0008 0008               None  2023.0             4583923.03
# 56898    0037 0037               None  2023.0             4582848.16
# 59026    0096 0096               None  2023.0             4581394.65
#
#       Coordenada_UTM_Y_ED50  Longitud_WGS84  Latitud_WGS84  \
# 2887                   None             NaN            NaN
# 3348                   None             NaN            NaN
# 4041                   None             NaN            NaN
# 8413                   None             NaN            NaN
# 10517                  None             NaN            NaN
# 10594                  None             NaN            NaN
# 11819                  None             NaN            NaN
# 12093                  None             NaN            NaN
# 12602                  None             NaN            NaN
# 12660                  None             NaN            NaN
# 13282                  None             NaN            NaN
# 13467                  None             NaN            NaN
# 16288                  None             NaN            NaN
# 19792                  None             NaN            NaN
# 30920                  None             NaN            NaN
# 31060                  None             NaN            NaN
# 31236                  None             NaN            NaN
# 33940                  None             NaN            NaN
# 34753                  None             NaN            NaN
# 34863                  None             NaN            NaN
# 35566                  None             NaN            NaN
# 36943            4584481.54        2.149706      41.406900
# 37394             4584360.4        2.172053      41.405971
# 37879            4585357.49        2.181268      41.415019
# 38495            4584366.47        2.185360      41.406121
# 39522            4582095.48        2.162615      41.385502
# 41668            4585247.52        2.142883      41.413749
# 44410            4581582.41             NaN            NaN
# 44564            4584868.03             NaN            NaN
# 44611            4584563.62             NaN            NaN
# 44949            4582237.63             NaN            NaN
# 45528            4581271.11             NaN            NaN
# 46801            4581661.62             NaN            NaN
# 47440            4585420.82             NaN            NaN
# 51252             4581549.1             NaN            NaN
# 51919            4583708.04             NaN            NaN
# 51995            4582593.13             NaN            NaN
# 53264            429116.73         2.150877      41.401878
# 56898            432648.07         2.193239      41.392500
# 59026            429629.64         2.157306      41.379150
#
#                                 Descripcio_causa_vianant
# 2887   Creuar per fora pas de vianants, Transitar a p...
# 3348              Altres, Desobeir el senyal del semàfor
# 4041   Creuar per fora pas de vianants, Transitar a p...
# 8413              Altres, Desobeir el senyal del semàfor
# 10517             Altres, Transitar a peu per la calçada
# 10594             Altres, Desobeir el senyal del semàfor
# 11819            Altres, Creuar per fora pas de vianants
# 12093  Creuar per fora pas de vianants, Desobeir el s...
# 12602  Creuar per fora pas de vianants, Transitar a p...
# 12660  Creuar per fora pas de vianants, Desobeir el s...
# 13282  Creuar per fora pas de vianants, Transitar a p...
# 13467             Altres, Desobeir el senyal del semàfor
# 16288  Creuar per fora pas de vianants, Desobeir el s...
# 19792             Altres, Desobeir el senyal del semàfor
# 30920  Creuar per fora pas de vianants, Desobeir el s...
# 31060            Altres, Creuar per fora pas de vianants
# 31236  Creuar per fora pas de vianants, Transitar a p...
# 33940             Altres, Desobeir el senyal del semàfor
# 34753             Altres, Transitar a peu per la calçada
# 34863             Altres, Desobeir el senyal del semàfor
# 35566             Altres, Desobeir el senyal del semàfor
# 36943             Altres, Desobeir el senyal del semàfor
# 37394  Creuar per fora pas de vianants, Transitar a p...
# 37879  Creuar per fora pas de vianants, Transitar a p...
# 38495  Creuar per fora pas de vianants, Desobeir el s...
# 39522  Creuar per fora pas de vianants, Transitar a p...
# 41668             Altres, Desobeir el senyal del semàfor
# 44410             Altres, Desobeir el senyal del semàfor
# 44564             Altres, Desobeir el senyal del semàfor
# 44611             Altres, Desobeir el senyal del semàfor
# 44949             Altres, Transitar a peu per la calçada
# 45528             Altres, Transitar a peu per la calçada
# 46801             Altres, Desobeir el senyal del semàfor
# 47440            Altres, Creuar per fora pas de vianants
# 51252             Altres, Desobeir el senyal del semàfor
# 51919  Creuar per fora pas de vianants, Desobeir altr...
# 51995  Creuar per fora pas de vianants, Transitar a p...
# 53264             Altres, Desobeir el senyal del semàfor
# 56898  Creuar per fora pas de vianants, Transitar a p...
# 59026  Creuar per fora pas de vianants, Transitar a p...
#
# [40 rows x 34 columns]

# %%
df_accidents.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Actualiza la columna existente Any con los valores de NK_Any cuando Any está vacía (NaN)
df_accidents["Any"] = df_accidents["Any"].combine_first(df_accidents["NK_Any"])

# Eliminar la columna redundante
df_accidents = df_accidents.drop(columns=["NK_Any"])

# %%
df_accidents.shape
# Out:
# (67448, 33)

# %%
df_accidents[['Num_postal', 'Num_postal ', 'Num_postal_caption']]
# Out:
#       Num_postal Num_postal  Num_postal_caption
# 0      0063 0063        None               None
# 1      0120 0120        None               None
# 2      0000 0000        None               None
# 3      0531 0531        None               None
# 4      0091 0091        None               None
# ...          ...         ...                ...
# 67443       None         603               None
# 67444       None         2-4               None
# 67445       None        None               None
# 67446       None         1-3               None
# 67447       None         25X               None
#
# [67448 rows x 3 columns]

# %%
df_accidents[df_accidents[['Num_postal', 'Num_postal ', 'Num_postal_caption']].notna().all(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Numero_expedient, Codi_districte, Nom_districte, Codi_barri, Nom_barri, Codi_carrer, Nom_carrer, Num_postal, Descripcio_dia_setmana, Dia_setmana, Descripcio_tipus_dia, Any, Mes_any, Nom_mes, Dia_mes, Hora_dia, Descripcio_torn, Numero_morts, Numero_lesionats_lleus, Numero_lesionats_greus, Numero_victimes, Numero_vehicles_implicats, Coordenada_UTM_X, Coordenada_UTM_Y, Longitud, Latitud, Num_postal , Num_postal_caption, Coordenada_UTM_X_ED50, Coordenada_UTM_Y_ED50, Longitud_WGS84, Latitud_WGS84, Descripcio_causa_vianant]
# Index: []
#
# [0 rows x 33 columns]

# %%
# Tenemos 3 variables redundates del numero postal
[col for col in df_accidents.columns if "Num_postal" in col]
# Out:
# ['Num_postal', 'Num_postal ', 'Num_postal_caption']

# %%
# Creamos columna unificada, priorizando la que ya se llama exactamente "Num_postal" que no tiene espacio
df_accidents["Num_postal"] = df_accidents["Num_postal"].combine_first(df_accidents["Num_postal "])
df_accidents["Num_postal"] = df_accidents["Num_postal"].combine_first(df_accidents["Num_postal_caption"])

# %%
# Eliminamos variables redundante mal nombrada con un espacio al final
df_accidents.drop(columns=['Num_postal ','Num_postal_caption'], inplace=True)

# %%
df_accidents.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67448 entries, 0 to 67447
# Data columns (total 31 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Numero_expedient           67448 non-null  object
#  1   Codi_districte             67448 non-null  int64
#  2   Nom_districte              67448 non-null  object
#  3   Codi_barri                 67448 non-null  object
#  4   Nom_barri                  67448 non-null  object
#  5   Codi_carrer                67448 non-null  int64
#  6   Nom_carrer                 67446 non-null  object
#  7   Num_postal                 59539 non-null  object
#  8   Descripcio_dia_setmana     67448 non-null  object
#  9   Dia_setmana                36549 non-null  object
#  10  Descripcio_tipus_dia       36549 non-null  object
#  11  Any                        67448 non-null  float64
#  12  Mes_any                    67448 non-null  int64
#  13  Nom_mes                    67448 non-null  object
#  14  Dia_mes                    67448 non-null  int64
#  15  Hora_dia                   67448 non-null  int64
#  16  Descripcio_torn            67448 non-null  object
#  17  Numero_morts               59923 non-null  float64
#  18  Numero_lesionats_lleus     66440 non-null  float64
#  19  Numero_lesionats_greus     60153 non-null  float64
#  20  Numero_victimes            66632 non-null  float64
#  21  Numero_vehicles_implicats  67448 non-null  int64
#  22  Coordenada_UTM_X           36549 non-null  object
#  23  Coordenada_UTM_Y           36549 non-null  object
#  24  Longitud                   44538 non-null  float64
#  25  Latitud                    44538 non-null  float64
#  26  Coordenada_UTM_X_ED50      30899 non-null  object
#  27  Coordenada_UTM_Y_ED50      30899 non-null  object
#  28  Longitud_WGS84             22886 non-null  float64
#  29  Latitud_WGS84              22886 non-null  float64
#  30  Descripcio_causa_vianant   60383 non-null  object
# dtypes: float64(9), int64(6), object(16)
# memory usage: 16.0+ MB

# %%
df_accidents[df_accidents[['Coordenada_UTM_Y_ED50', 'Coordenada_UTM_X_ED50', 'Coordenada_UTM_X', 'Coordenada_UTM_Y' ]].notna().all(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Numero_expedient, Codi_districte, Nom_districte, Codi_barri, Nom_barri, Codi_carrer, Nom_carrer, Num_postal, Descripcio_dia_setmana, Dia_setmana, Descripcio_tipus_dia, Any, Mes_any, Nom_mes, Dia_mes, Hora_dia, Descripcio_torn, Numero_morts, Numero_lesionats_lleus, Numero_lesionats_greus, Numero_victimes, Numero_vehicles_implicats, Coordenada_UTM_X, Coordenada_UTM_Y, Longitud, Latitud, Coordenada_UTM_X_ED50, Coordenada_UTM_Y_ED50, Longitud_WGS84, Latitud_WGS84, Descripcio_causa_vianant]
# Index: []
#
# [0 rows x 31 columns]

# %%
# Actualizamos las variables de las coordenadas combinadolas con sus variables redundantes 
df_accidents['Longitud'] = df_accidents['Longitud'].combine_first(df_accidents['Longitud_WGS84'])
df_accidents['Latitud'] = df_accidents['Latitud'].combine_first(df_accidents['Latitud_WGS84'])
df_accidents['Coordenada_UTM_X'] = df_accidents['Coordenada_UTM_X'].combine_first(df_accidents['Coordenada_UTM_X_ED50'])
df_accidents['Coordenada_UTM_Y'] = df_accidents['Coordenada_UTM_Y'].combine_first(df_accidents['Coordenada_UTM_Y_ED50'])

# %%
# Eliminamos las variables redundante
df_accidents.drop(columns=['Longitud_WGS84', 'Latitud_WGS84','Coordenada_UTM_X_ED50', 'Coordenada_UTM_Y_ED50'], inplace=True)

# %%
df_accidents.isna().sum().sort_values(ascending=False)
# Out:
# Dia_setmana                  30899
# Descripcio_tipus_dia         30899
# Num_postal                    7909
# Numero_morts                  7525
# Numero_lesionats_greus        7295
# Descripcio_causa_vianant      7065
# Numero_lesionats_lleus        1008
# Numero_victimes                816
# Longitud                        24
# Latitud                         24
# Nom_carrer                       2
# Descripcio_dia_setmana           0
# Codi_barri                       0
# Nom_barri                        0
# Codi_carrer                      0
# Codi_districte                   0
# Numero_expedient                 0
# Nom_districte                    0
# Any                              0
# Hora_dia                         0
# Descripcio_torn                  0
# Nom_mes                          0
# Dia_mes                          0
# Mes_any                          0
# Numero_vehicles_implicats        0
# Coordenada_UTM_X                 0
# Coordenada_UTM_Y                 0
# dtype: int64

# %%
df_accidents.shape
# Out:
# (67448, 27)

# %%
df_accidents["Any"].value_counts().sort_index()
# Out:
# Any
# 2017.0    10335
# 2018.0     9926
# 2019.0    10027
# 2020.0     6261
# 2021.0     7653
# 2022.0     7989
# 2023.0     7721
# 2024.0     7536
# Name: count, dtype: int64

# %%
df_accidents['Descripcio_dia_setmana'].value_counts()
# Out:
# Descripcio_dia_setmana
# Divendres    11329
# Dijous       10988
# Dimecres     10805
# Dimarts      10598
# Dilluns      10074
# Dissabte      7721
# Diumenge      5933
# Name: count, dtype: int64

# %%
# Codificamos correctamente los dias de la semana actualizando la variable Dia_setmana (mal codificada)
dias_semana = {'Dilluns': 1,
               'Dimarts': 2,
               'Dimecres': 3,
               'Dijous': 4,
               'Divendres': 5,
               'Dissabte': 6,
               'Diumenge': 7}

df_accidents['Dia_setmana'] = df_accidents['Descripcio_dia_setmana'].map(dias_semana)
df_accidents['Dia_setmana'].value_counts()
# Out:
# Dia_setmana
# 5    11329
# 4    10988
# 3    10805
# 2    10598
# 1    10074
# 6     7721
# 7     5933
# Name: count, dtype: int64

# %%
df_accidents['Nom_barri'].value_counts()
# Out:
# Nom_barri
# la Dreta de l'Eixample             7083
# l'Antiga Esquerra de l'Eixample    3587
# Sant Gervasi - Galvany             2629
# la Nova Esquerra de l'Eixample     2523
# la Sagrada Família                 2460
#                                    ...
# Can Baró                            106
# Ciutat Meridiana                     88
# Torre Baró                           75
# Can Peguera                          48
# Vallbona                             43
# Name: count, Length: 75, dtype: int64

# %%
df_accidents['Codi_barri'].value_counts()
# Out:
# Codi_barri
# 7          6454
# 8          3232
# 26         2384
# 9          2275
# 6          2220
#            ...
# 81-8-55      10
# 81-8-54       8
# 71-7-42       7
# 81-8-56       6
# 84-8-47       2
# Name: count, Length: 148, dtype: int64

# %%
df_accidents.shape
# Out:
# (67448, 27)

# %%
df_accidents = limpiar_clave(df_accidents, "Numero_expedient")

# --- Dataset 1: causa conductor ---
df_causa_conductor = cargar_y_unificar(
    "../data/raw/accidents_causa_conductor",
    ["Numero_expedient", "Número_expedient"],
    ["Descripcio_causa_mediata", "Descripcio_torn"]
)

# --- Dataset 2: causa mediata ---
df_causa_mediata = cargar_y_unificar(
    "../data/raw/accidents_causa_mediata",
    ["Numero_expedient", "Número_d'expedient"],
    ["Descripcio_causa_mediata", "Descripció_causa_mediata"]
)

# --- Dataset 3: tipología ---
df_tipologia = cargar_y_unificar(
    "../data/raw/accidents_segun_tipologia",
    ["Numero_expedient", "Codi_expedient"],
    ["Descripcio_tipus_accident", "Tipus_accident"]
)

df_causa_conductor = df_causa_conductor.rename(columns={'Descripcio_causa_mediata':'Descripcio_causa_conductor'})

# --- Merge final con df_accidents ---
df_accidents = df_accidents.merge(df_causa_conductor, on="Numero_expedient", how="left")
df_accidents = df_accidents.merge(df_causa_mediata, on="Numero_expedient", how="left")
df_accidents = df_accidents.merge(df_tipologia, on="Numero_expedient", how="left")

# %%
# Crear un filtro booleano que indique si alguna de las palabras aparece en la columna
filtro = df_causa_conductor['Descripcio_causa_conductor'].str.contains(r'\b(matí|Tarda|Nit)\b', case=False, na=False)

# Mostrar cuántos registros cumplen la condición
f"Número de registros que contienen alguna de las palabras: {filtro.sum()}"
# Out:
# /tmp/ipykernel_1688/426766472.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   filtro = df_causa_conductor['Descripcio_causa_conductor'].str.contains(r'\b(matí|Tarda|Nit)\b', case=False, na=False)
# 'Número de registros que contienen alguna de las palabras: 0'

# %%
df_accidents.shape
# Out:
# (67448, 30)

# %%
df_accidents['Descripcio_tipus_accident'].value_counts()
# Out:
# Descripcio_tipus_accident
# Col.lisió lateral                                                                  15021
# Abast                                                                              13619
# Col.lisió fronto-lateral                                                           11484
# Atropellament                                                                       7640
# Caiguda (dues rodes)                                                                5042
#                                                                                    ...
# Caiguda (dues rodes), Resta sortides de via, Sortida de via amb xoc o col.lisió        1
# Sortida de via amb atropellament                                                       1
# Abast multiple, Atropellament                                                          1
# Caiguda (dues rodes), Caiguda interior vehicle, Col.lisió lateral                      1
# Col.lisió frontal, Sortida de via amb xoc o col.lisió                                  1
# Name: count, Length: 151, dtype: int64

# %%
df_accidents.isna().sum().sort_values(ascending=False)
# Out:
# Descripcio_tipus_dia          30899
# Num_postal                     7909
# Numero_morts                   7525
# Numero_lesionats_greus         7295
# Descripcio_causa_vianant       7065
# Descripcio_causa_mediata       7039
# Numero_lesionats_lleus         1008
# Numero_victimes                 816
# Descripcio_causa_conductor      408
# Latitud                          24
# Longitud                         24
# Nom_carrer                        2
# Descripcio_tipus_accident         2
# Nom_districte                     0
# Nom_mes                           0
# Mes_any                           0
# Any                               0
# Dia_setmana                       0
# Descripcio_dia_setmana            0
# Codi_barri                        0
# Nom_barri                         0
# Codi_carrer                       0
# Codi_districte                    0
# Numero_expedient                  0
# Hora_dia                          0
# Descripcio_torn                   0
# Numero_vehicles_implicats         0
# Dia_mes                           0
# Coordenada_UTM_X                  0
# Coordenada_UTM_Y                  0
# dtype: int64

# %%
df_accidents['Numero_morts'].value_counts()
# Out:
# Numero_morts
# 0.0    59786
# 1.0      137
# Name: count, dtype: int64

# %%
df_accidents
# Out:
#       Numero_expedient  Codi_districte        Nom_districte Codi_barri  \
# 0          2017S000001               5  Sarrià-Sant Gervasi         26
# 1          2017S000002               2             Eixample          5
# 2          2017S000003               7       Horta-Guinardó         33
# 3          2017S000004               2             Eixample          6
# 4          2017S000005              10           Sant Martí         66
# ...                ...             ...                  ...        ...
# 67443      2024S007547               2             Eixample          7
# 67444      2024S007548               1         Ciutat Vella          4
# 67445      2024S007549               3       Sants-Montjuïc         11
# 67446      2024S007550               3       Sants-Montjuïc         11
# 67447      2024S007551               1         Ciutat Vella          1
#
#                                    Nom_barri  Codi_carrer  \
# 0                     Sant Gervasi - Galvany       187105
# 1                              el Fort Pienc       197302
# 2                           el Baix Guinardó       265402
# 3                         la Sagrada Família        89004
# 4          el Parc i la Llacuna del Poblenou       243206
# ...                                      ...          ...
# 67443                 la Dreta de l'Eixample       169409
# 67444  Sant Pere, Santa Caterina i la Ribera       143100
# 67445                           el Poble Sec       198804
# 67446                           el Poble Sec       234001
# 67447                               el Raval       701367
#
#                                               Nom_carrer Num_postal  \
# 0      VIA AUGUSTA                                   ...  0063 0063
# 1      GV CORTS CATALANES                            ...  0120 0120
# 2      RDA GUINARDÓ                                  ...  0000 0000
# 3      BALMES / Rosselló                             ...  0531 0531
# 4      PALLARS                                       ...  0091 0091
# ...                                                  ...        ...
# 67443                                    Corts Catalanes        603
# 67444                          General Álvarez de Castro        2-4
# 67445                                          Paral·lel       None
# 67446                                            Olímpic        1-3
# 67447                                              Raval        25X
#
#       Descripcio_dia_setmana  Dia_setmana  ... Numero_victimes  \
# 0                   Diumenge            7  ...             1.0
# 1                   Diumenge            7  ...             1.0
# 2                   Diumenge            7  ...             0.0
# 3                   Diumenge            7  ...             1.0
# 4                   Diumenge            7  ...             2.0
# ...                      ...          ...  ...             ...
# 67443                Dimarts            2  ...             1.0
# 67444               Dissabte            6  ...             NaN
# 67445                 Dijous            4  ...             1.0
# 67446                Dilluns            1  ...             1.0
# 67447              Divendres            5  ...             1.0
#
#        Numero_vehicles_implicats  Coordenada_UTM_X Coordenada_UTM_Y  Longitud  \
# 0                              1         428887,27        4583659,1  2.151330
# 1                              2         431987,02       4583282,61  2.182376
# 2                              1         430178,13       4585222,02  2.166464
# 3                              2         431615,63       4583971,63  2.157359
# 4                              3         432466,78       4583327,27  2.193249
# ...                          ...               ...              ...       ...
# 67443                          1       4582460.824       430450.705  2.167002
# 67444                          1       4582233.737       431382.242  2.178169
# 67445                          1        4580940.29       428989.313  2.149703
# 67446                          1       4579426.054       429206.725  2.152479
# 67447                          1       4581341.695       430668.432  2.169734
#
#          Latitud  Descripcio_causa_vianant  \
# 0      41.400771  No és causa del  vianant
# 1      41.399680  No és causa del  vianant
# 2      41.412769  No és causa del  vianant
# 3      41.393310  No és causa del  vianant
# 4      41.397908  No és causa del  vianant
# ...          ...                       ...
# 67443  41.388825                    Altres
# 67444  41.386859                      <NA>
# 67445  41.375002                      <NA>
# 67446  41.361383                      <NA>
# 67447  41.378764                      <NA>
#
#                               Descripcio_causa_conductor  \
# 0                 Altres, Manca d'atenció a la conducció
# 1                         Manca d'atenció a la conducció
# 2                                                 Altres
# 3      Desobeir altres senyals, Gir indegut o sense p...
# 4                                                 Altres
# ...                                                  ...
# 67443                                     No determinada
# 67444                                     No determinada
# 67445                                     No determinada
# 67446                     Manca d'atenció a la conducció
# 67447                                                NaN
#
#        Descripcio_causa_mediata          Descripcio_tipus_accident
# 0                   Alcoholèmia         Xoc contra element estàtic
# 1        No hi ha causa mediata           Col.lisió fronto-lateral
# 2        No hi ha causa mediata         Xoc contra element estàtic
# 3        No hi ha causa mediata                  Col.lisió lateral
# 4                   Alcoholèmia  Abast, Xoc contra element estàtic
# ...                         ...                                ...
# 67443                      <NA>                      Atropellament
# 67444                      <NA>         Xoc contra element estàtic
# 67445                      <NA>           Caiguda interior vehicle
# 67446               Alcoholèmia         Xoc contra element estàtic
# 67447                       NaN                                NaN
#
# [67448 rows x 30 columns]

# %%
df_accidents
# Out:
#       Numero_expedient  Codi_districte        Nom_districte Codi_barri  \
# 0          2017S000001               5  Sarrià-Sant Gervasi         26
# 1          2017S000002               2             Eixample          5
# 2          2017S000003               7       Horta-Guinardó         33
# 3          2017S000004               2             Eixample          6
# 4          2017S000005              10           Sant Martí         66
# ...                ...             ...                  ...        ...
# 67443      2024S007547               2             Eixample          7
# 67444      2024S007548               1         Ciutat Vella          4
# 67445      2024S007549               3       Sants-Montjuïc         11
# 67446      2024S007550               3       Sants-Montjuïc         11
# 67447      2024S007551               1         Ciutat Vella          1
#
#                                    Nom_barri  Codi_carrer  \
# 0                     Sant Gervasi - Galvany       187105
# 1                              el Fort Pienc       197302
# 2                           el Baix Guinardó       265402
# 3                         la Sagrada Família        89004
# 4          el Parc i la Llacuna del Poblenou       243206
# ...                                      ...          ...
# 67443                 la Dreta de l'Eixample       169409
# 67444  Sant Pere, Santa Caterina i la Ribera       143100
# 67445                           el Poble Sec       198804
# 67446                           el Poble Sec       234001
# 67447                               el Raval       701367
#
#                                               Nom_carrer Num_postal  \
# 0      VIA AUGUSTA                                   ...  0063 0063
# 1      GV CORTS CATALANES                            ...  0120 0120
# 2      RDA GUINARDÓ                                  ...  0000 0000
# 3      BALMES / Rosselló                             ...  0531 0531
# 4      PALLARS                                       ...  0091 0091
# ...                                                  ...        ...
# 67443                                    Corts Catalanes        603
# 67444                          General Álvarez de Castro        2-4
# 67445                                          Paral·lel       None
# 67446                                            Olímpic        1-3
# 67447                                              Raval        25X
#
#       Descripcio_dia_setmana  Dia_setmana  ... Numero_victimes  \
# 0                   Diumenge            7  ...             1.0
# 1                   Diumenge            7  ...             1.0
# 2                   Diumenge            7  ...             0.0
# 3                   Diumenge            7  ...             1.0
# 4                   Diumenge            7  ...             2.0
# ...                      ...          ...  ...             ...
# 67443                Dimarts            2  ...             1.0
# 67444               Dissabte            6  ...             NaN
# 67445                 Dijous            4  ...             1.0
# 67446                Dilluns            1  ...             1.0
# 67447              Divendres            5  ...             1.0
#
#        Numero_vehicles_implicats  Coordenada_UTM_X Coordenada_UTM_Y  Longitud  \
# 0                              1         428887,27        4583659,1  2.151330
# 1                              2         431987,02       4583282,61  2.182376
# 2                              1         430178,13       4585222,02  2.166464
# 3                              2         431615,63       4583971,63  2.157359
# 4                              3         432466,78       4583327,27  2.193249
# ...                          ...               ...              ...       ...
# 67443                          1       4582460.824       430450.705  2.167002
# 67444                          1       4582233.737       431382.242  2.178169
# 67445                          1        4580940.29       428989.313  2.149703
# 67446                          1       4579426.054       429206.725  2.152479
# 67447                          1       4581341.695       430668.432  2.169734
#
#          Latitud  Descripcio_causa_vianant  \
# 0      41.400771  No és causa del  vianant
# 1      41.399680  No és causa del  vianant
# 2      41.412769  No és causa del  vianant
# 3      41.393310  No és causa del  vianant
# 4      41.397908  No és causa del  vianant
# ...          ...                       ...
# 67443  41.388825                    Altres
# 67444  41.386859                      <NA>
# 67445  41.375002                      <NA>
# 67446  41.361383                      <NA>
# 67447  41.378764                      <NA>
#
#                               Descripcio_causa_conductor  \
# 0                 Altres, Manca d'atenció a la conducció
# 1                         Manca d'atenció a la conducció
# 2                                                 Altres
# 3      Desobeir altres senyals, Gir indegut o sense p...
# 4                                                 Altres
# ...                                                  ...
# 67443                                     No determinada
# 67444                                     No determinada
# 67445                                     No determinada
# 67446                     Manca d'atenció a la conducció
# 67447                                                NaN
#
#        Descripcio_causa_mediata          Descripcio_tipus_accident
# 0                   Alcoholèmia         Xoc contra element estàtic
# 1        No hi ha causa mediata           Col.lisió fronto-lateral
# 2        No hi ha causa mediata         Xoc contra element estàtic
# 3        No hi ha causa mediata                  Col.lisió lateral
# 4                   Alcoholèmia  Abast, Xoc contra element estàtic
# ...                         ...                                ...
# 67443                      <NA>                      Atropellament
# 67444                      <NA>         Xoc contra element estàtic
# 67445                      <NA>           Caiguda interior vehicle
# 67446               Alcoholèmia         Xoc contra element estàtic
# 67447                       NaN                                NaN
#
# [67448 rows x 30 columns]

# %%
# Guardamos el dataframe
with open('../data/processed/df_accidents.pkl', 'wb') as f:
    pickle.dump(df_accidents, f)

# %%
with open('../data/processed/df-meteo.pkl', 'rb') as f:
    df_meteo = pickle.load(f)

# %%
df_meteo
# Out:
#         location_id              time  temperature_2m (°C)  \
# 0                 0  2017-01-01T00:00                  7.2
# 1                 0  2017-01-01T01:00                  7.0
# 2                 0  2017-01-01T02:00                  4.2
# 3                 0  2017-01-01T03:00                  4.7
# 4                 0  2017-01-01T04:00                  4.4
# ...             ...               ...                  ...
# 701275            9  2024-12-31T19:00                  9.1
# 701276            9  2024-12-31T20:00                  9.0
# 701277            9  2024-12-31T21:00                  8.4
# 701278            9  2024-12-31T22:00                  7.8
# 701279            9  2024-12-31T23:00                  7.7
#
#         precipitation (mm)  snowfall (cm)  wind_speed_10m (km/h)  rain (mm)  \
# 0                      0.0            0.0                    7.1        0.0
# 1                      0.0            0.0                    8.9        0.0
# 2                      0.0            0.0                   11.0        0.0
# 3                      0.0            0.0                   10.8        0.0
# 4                      0.0            0.0                   10.5        0.0
# ...                    ...            ...                    ...        ...
# 701275                 0.0            0.0                    1.1        0.0
# 701276                 0.0            0.0                    3.4        0.0
# 701277                 0.0            0.0                    6.6        0.0
# 701278                 0.0            0.0                    8.1        0.0
# 701279                 0.0            0.0                    8.4        0.0
#
#                     time_n
# 0      2017-01-01 00:00:00
# 1      2017-01-01 01:00:00
# 2      2017-01-01 02:00:00
# 3      2017-01-01 03:00:00
# 4      2017-01-01 04:00:00
# ...                    ...
# 701275 2024-12-31 19:00:00
# 701276 2024-12-31 20:00:00
# 701277 2024-12-31 21:00:00
# 701278 2024-12-31 22:00:00
# 701279 2024-12-31 23:00:00
#
# [701280 rows x 8 columns]

# %%
df_accidents['Any'] = df_accidents['Any'].astype(int)
df_accidents['Any'].dtype
# Out:
# dtype('int64')

# %%
df_accidents['time_n'] = pd.to_datetime(df_accidents.apply(lambda x: f"{x['Any']}-{x['Mes_any']}-{x['Dia_mes']} {x['Hora_dia']}:00:00", axis=1))

# %%
df_meteo['time_n'] = pd.to_datetime(df_meteo['time'])

# %%
mapeo_distritos = {'Desconegut': 0,              # Montjuïc
                   'Sant Martí': 8,              # Zona marítima noreste
                   'Ciutat Vella': 0,            # Centro histórico
                   'Eixample': 1,                # Centro denso
                   'Sants-Montjuïc': 2,          # Sur de la ciudad
    'Les Corts': 3,               # Suroeste
    'Sarrià-Sant Gervasi': 4,     # Zona alta
    'Gràcia': 5,                  # Centro-norte
    'Horta-Guinardó': 6,          # Noreste
    'Nou Barris': 7,              # Norte
    'Sant Andreu': 9}             # Nordeste

# %%
df_accidents['location_id'] = df_accidents['Nom_districte'].map(mapeo_distritos)

# %%
df_merged = pd.merge(df_accidents, df_meteo, on=['time_n', 'location_id'], how='right')
df_merged
# Out:
#        Numero_expedient  Codi_districte Nom_districte Codi_barri Nom_barri  \
# 0                   NaN             NaN           NaN        NaN       NaN
# 1                   NaN             NaN           NaN        NaN       NaN
# 2                   NaN             NaN           NaN        NaN       NaN
# 3                   NaN             NaN           NaN        NaN       NaN
# 4                   NaN             NaN           NaN        NaN       NaN
# ...                 ...             ...           ...        ...       ...
# 707892              NaN             NaN           NaN        NaN       NaN
# 707893              NaN             NaN           NaN        NaN       NaN
# 707894              NaN             NaN           NaN        NaN       NaN
# 707895              NaN             NaN           NaN        NaN       NaN
# 707896              NaN             NaN           NaN        NaN       NaN
#
#         Codi_carrer Nom_carrer Num_postal Descripcio_dia_setmana  Dia_setmana  \
# 0               NaN        NaN        NaN                    NaN          NaN
# 1               NaN        NaN        NaN                    NaN          NaN
# 2               NaN        NaN        NaN                    NaN          NaN
# 3               NaN        NaN        NaN                    NaN          NaN
# 4               NaN        NaN        NaN                    NaN          NaN
# ...             ...        ...        ...                    ...          ...
# 707892          NaN        NaN        NaN                    NaN          NaN
# 707893          NaN        NaN        NaN                    NaN          NaN
# 707894          NaN        NaN        NaN                    NaN          NaN
# 707895          NaN        NaN        NaN                    NaN          NaN
# 707896          NaN        NaN        NaN                    NaN          NaN
#
#         ... Descripcio_causa_mediata  Descripcio_tipus_accident  \
# 0       ...                      NaN                        NaN
# 1       ...                      NaN                        NaN
# 2       ...                      NaN                        NaN
# 3       ...                      NaN                        NaN
# 4       ...                      NaN                        NaN
# ...     ...                      ...                        ...
# 707892  ...                      NaN                        NaN
# 707893  ...                      NaN                        NaN
# 707894  ...                      NaN                        NaN
# 707895  ...                      NaN                        NaN
# 707896  ...                      NaN                        NaN
#
#                     time_n location_id              time  temperature_2m (°C)  \
# 0      2017-01-01 00:00:00           0  2017-01-01T00:00                  7.2
# 1      2017-01-01 01:00:00           0  2017-01-01T01:00                  7.0
# 2      2017-01-01 02:00:00           0  2017-01-01T02:00                  4.2
# 3      2017-01-01 03:00:00           0  2017-01-01T03:00                  4.7
# 4      2017-01-01 04:00:00           0  2017-01-01T04:00                  4.4
# ...                    ...         ...               ...                  ...
# 707892 2024-12-31 19:00:00           9  2024-12-31T19:00                  9.1
# 707893 2024-12-31 20:00:00           9  2024-12-31T20:00                  9.0
# 707894 2024-12-31 21:00:00           9  2024-12-31T21:00                  8.4
# 707895 2024-12-31 22:00:00           9  2024-12-31T22:00                  7.8
# 707896 2024-12-31 23:00:00           9  2024-12-31T23:00                  7.7
#
#        precipitation (mm)  snowfall (cm)  wind_speed_10m (km/h)  rain (mm)
# 0                     0.0            0.0                    7.1        0.0
# 1                     0.0            0.0                    8.9        0.0
# 2                     0.0            0.0                   11.0        0.0
# 3                     0.0            0.0                   10.8        0.0
# 4                     0.0            0.0                   10.5        0.0
# ...                   ...            ...                    ...        ...
# 707892                0.0            0.0                    1.1        0.0
# 707893                0.0            0.0                    3.4        0.0
# 707894                0.0            0.0                    6.6        0.0
# 707895                0.0            0.0                    8.1        0.0
# 707896                0.0            0.0                    8.4        0.0
#
# [707897 rows x 38 columns]

# %%
df_merged["accident"] = df_merged["Numero_expedient"].notna().astype(int)

# %%
df_merged['accident'].value_counts() / len(df_merged)
# Out:
# accident
# 0    0.904721
# 1    0.095279
# Name: count, dtype: float64
